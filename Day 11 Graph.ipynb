# %% [markdown]
# ## Creating graph

# %%
class Graph:
    def __init__(self,nVertices):
        self.nVertices=nVertices
        self.adjMatrix=[[0 for i in range(nVertices)] for j in range(nVertices)]
    
    def addEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=1
        self.adjMatrix[v2][v1]=1
    
    def removeEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=0
        self.adjMatrix[v2][v1]=0
        
    def ContainsEdge(self,v1,v2):
        return True if self.adjMatrix[v1][v2]>0 else False
    
    def __str__(self):
        return str(self.adjMatrix)
g=Graph(5)
g.addEdge(0,1)
g.addEdge(1,3)
g.addEdge(2,4)
print(g)

# %% [markdown]
# ## DFS Function

# %%
import queue
class Graph:
    def __init__(self,nVertices):
        self.nVertices=nVertices
        self.adjMatrix=[[0 for i in range(nVertices)] for j in range(nVertices)]
    
    def addEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=1
        self.adjMatrix[v2][v1]=1

        
        
    def bfs(self,s,d):
        q=queue.Queue()
        q.put(s)
        visited=[False for i in range(self.nVertices)]
        visited[s]=True
        
        while q.empty() is False:
            u=q.get()
            if u==d:
                return True
            for i in range(self.nVertices):
                if (self.adjMatrix[u][i]>0 and visited[i] is False):
                    q.put(i)
                    visited[i]=True
        return False       
                
    
  
    
    
    def removeEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=0
        self.adjMatrix[v2][v1]=0
        
    def ContainsEdge(self,v1,v2):
        return True if self.adjMatrix[v1][v2]>0 else False
    
    def __str__(self):
        return str(self.adjMatrix)
g=Graph(5)
g.addEdge(0,1)
g.addEdge(1,3)
g.addEdge(2,4)
g.addEdge(2,3)
g.addEdge(0,2)
if g.bfs(1,4):
    print("It has Path")
else:
    print("it has no path")

# %% [markdown]
# ## HAs Path

# %%
import queue
class Graph:
    def __init__(self,nVertices):
        self.nVertices=nVertices
        self.adjMatrix=[[0 for i in range(nVertices)] for j in range(nVertices)]
    
    def addEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=1
        self.adjMatrix[v2][v1]=1

        
        
    def bfs(self,s,d):
        q=queue.Queue()
        q.put(s)
        visited=[False for i in range(self.nVertices)]
        visited[s]=True
        
        while q.empty() is False:
            u=q.get()
            if u==d:
                return True
            for i in range(self.nVertices):
                if (self.adjMatrix[u][i]>0 and visited[i] is False):
                    q.put(i)
                    visited[i]=True
        return False       
                
    def check(self):
        visited=[]
        for i in range(self.nVertices):
            if self.bfs(0,i):
                visited.append(True)
            else:
                visited.append(False)
                
        return visited
        
                
  
    
    
    def removeEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=0
        self.adjMatrix[v2][v1]=0
        
    def ContainsEdge(self,v1,v2):
        return True if self.adjMatrix[v1][v2]>0 else False
    
    def __str__(self):
        return str(self.adjMatrix)
g=Graph(5)
g.addEdge(0,1)
g.addEdge(3,2)
if False in g.check():
    print("Not connected")
else:
    print("Connected")

# %% [markdown]
# ## DFS For Disconnected Graph

# %%
import queue
class Graph:
    def __init__(self,nVertices):
        self.nVertices=nVertices
        self.adjMatrix=[[0 for i in range(nVertices)] for j in range(nVertices)]
    
    def addEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=1
        self.adjMatrix[v2][v1]=1
    
    def __dfsHelper(self,sv,visited):
        print(sv)
        
        visited[sv]=True
        for i in range(self.nVertices):
            
            if (self.adjMatrix[sv][i]>0 and visited[i] is False):
                
                self.__dfsHelper(i,visited)
        
    def dfs(self):
        visited=[False for i in range(self.nVertices)]
        for i in range(self.nVertices):
            
            if visited[i] is False:
                
                self.__dfsHelper(i,visited)
        
    
    
    def removeEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=0
        self.adjMatrix[v2][v1]=0
        
    def ContainsEdge(self,v1,v2):
        return True if self.adjMatrix[v1][v2]>0 else False
    
    def __str__(self):
        return str(self.adjMatrix)
g=Graph(7)
g.addEdge(0,1)
g.addEdge(0,3)
g.addEdge(2,5)
g.addEdge(2,4)
g.addEdge(4,6)

g.dfs()

# %% [markdown]
# ## BFS

# %%
import queue
class Graph:
    def __init__(self,nVertices):
        self.nVertices=nVertices
        self.adjMatrix=[[0 for i in range(nVertices)] for j in range(nVertices)]
    
    def addEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=1
        self.adjMatrix[v2][v1]=1
    
    def bfs(self,sv):
        visited=[False for i in range(self.nVertices)]
        q=queue.Queue()
        q.put(sv)
        visited[sv]=True
        while q.empty() is False:
            u=q.get()
            print(u)
            for i in range(self.nVertices):
                if (self.adjMatrix[u][i]>0 and visited[i] is False):
                    q.put(i)
                    visited[i]=True
    
    
    def removeEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=0
        self.adjMatrix[v2][v1]=0
        
    def ContainsEdge(self,v1,v2):
        return True if self.adjMatrix[v1][v2]>0 else False
    
    def __str__(self):
        return str(self.adjMatrix)
g=Graph(7)
g.addEdge(0,1)
g.addEdge(0,3)
g.addEdge(2,5)
g.addEdge(2,4)
g.addEdge(4,6)

g.bfs(0)

# %% [markdown]
# ## Print All path DFS

# %%
class Graph:
    def __init__(self,nVertices):
        self.nVertices=nVertices
        self.adjMatrix=[[0 for i in range(nVertices)] for j in range(nVertices)]
    
    def addEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=1
        self.adjMatrix[v2][v1]=1
        
    def removeEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=0
        self.adjMatrix[v2][v1]=0
        
    def containedge(self):
        return True if self.adjMatrix[v1][v2]>0 else False
    
    def printallpathhelper(self,s,d,visited,path):
        visited[s]=True
        path.append(s)
        if s==d:
            print(path)
        else:
            for i in range(self.nVertices):
                if self.adjMatrix[s][i]>0 and visited[i] is False:
                    self.printallpathhelper(i,d,visited,path)
                    
        path.pop()
        visited[s]=False
        
    
    def printallpath(self,s,d):
        visited=[False for i in range(self.nVertices)]
        path=[]
        self.printallpathhelper(s,d,visited,path)
        
        
g=Graph(6)
g.addEdge(0,1)
g.addEdge(0,2)
g.addEdge(0,3)
g.addEdge(1,5)
g.addEdge(2,4)
g.printallpath(1,3)

# %% [markdown]
# ## has connected

# %%
import queue
class Graph:
    def __init__(self,nVertices):
        self.nVertices=nVertices
        self.adjMatrix=[[0 for i in range(nVertices)] for j in range(nVertices)]
    
    def addEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=1
        self.adjMatrix[v2][v1]=1

        
        
    def bfs(self,s,d):
        q=queue.Queue()
        q.put(s)
        visited=[False for i in range(self.nVertices)]
        visited[s]=True
        
        while q.empty() is False:
            u=q.get()
            if u==d:
                return True
            for i in range(self.nVertices):
                if (self.adjMatrix[u][i]>0 and visited[i] is False):
                    q.put(i)
                    visited[i]=True
        return False       
                
    def check(self):
        visited=[]
        for i in range(self.nVertices):
            if self.bfs(0,i):
                visited.append(True)
            else:
                visited.append(False)
                
        return visited
        
                
  
    
    
    def removeEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=0
        self.adjMatrix[v2][v1]=0
        
    def ContainsEdge(self,v1,v2):
        return True if self.adjMatrix[v1][v2]>0 else False
    
    def __str__(self):
        return str(self.adjMatrix)
g=Graph(5)
g.addEdge(0,1)
g.addEdge(3,2)
if False in g.check():
    print("Not connected")
else:
    print("Connected")

# %% [markdown]
# ## All Connected Component

# %%
import queue
class Graph:
    def __init__(self,nVertices):
        self.nVertices=nVertices
        self.adjMatrix=[[0 for i in range(nVertices)] for j in range(nVertices)]
    
    def addEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=1
        self.adjMatrix[v2][v1]=1

        
        
    def all_connected_component(self,temp,i,visited):
        u=visited[i]
        visited[i]=True
        temp.append(i)
        for i in range(self.nVertices):
            if (self.adjMatrix[u][i]>0 and visited[i] is False):
                temp=self.all_connected_component(temp,i,visited)
        return temp
        
        
                
    def check(self):
        visited=[False for i in range(self.nVertices)]
        cc=[]
        for i in range(self.nVertices):
            if visited[i]==False:
                cc.append(self.all_connected_component(temp,i,visited))
        return cc
        
        
            
           
    
    
    def removeEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=0
        self.adjMatrix[v2][v1]=0
        
    def ContainsEdge(self,v1,v2):
        return True if self.adjMatrix[v1][v2]>0 else False
    
    def __str__(self):
        return str(self.adjMatrix)
g=Graph(5)
g.addEdge(0,1)
g.addEdge(3,2)
cc=g.check()
print(cc)

# %% [markdown]
# ## Krushkal Algo

# %%
class Edge:
    def __init__(self,src,dest,wt):
        
        self.src=src
        self.dest=dest
        self.wt=wt
        

def getParent(v,parent):
    if (v==parent[v]):
        return v
    return getParent(parent[v],parent)

def krushkal(edges,nVertices):
    parent=[i for i in range(nVertices)]
    edges=sorted(edges,key= lambda edge:edge.wt)
    count=0
    i=0
    output=[]
    while count <(nVertices-1):
        CurrentEdge=edges[i]
        
        srcParent=getParent(CurrentEdge.src,parent)
        
        destParent=getParent(CurrentEdge.dest,parent)
        
        if srcParent != destParent:
            output.append(CurrentEdge)
            count +=1
            parent[srcParent]=destParent
        i +=1
    return output

li=[int(ele) for ele in input().split()]
n=li[0]
E=li[1]
edges=[]
for i in range(E):
    curr_input=[int(ele) for ele in input().split()]
    src=curr_input[0]
    dest=curr_input[1]
    wt=curr_input[2]
    edge=Edge(src,dest,wt)
    edges.append(edge)
print("edges are",edges)   
output=krushkal(edges,n)

for edge in output:
    if edge.src < edge.dest:
        print(str(edge.src) + " " +str(edge.dest) + " "  + str(edge.wt))
    else:
        print(str(edge.dest) + " " + str(edge.src) + " "  + str(edge.wt))

# %% [markdown]
# ## Practice

# %%
class Graph:
    def __init__(self,nVertices):
        self.nVertices=nVertices
        self.adjMatrix=[[0 for i in range(nVertices)] for j in range(nVertices)]
    
    def addEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=1
        self.adjMatrix[v2][v1]=1
    
    def removeEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=0
        self.adjMatrix[v2][v1]=0
        
    def ContainsEdge(self,v1,v2):
        return True if self.adjMatrix[v1][v2]>0 else False
    
    def __str__(self):
        return str(self.adjMatrix)
g=Graph(5)
g.addEdge(0,1)
g.addEdge(1,3)
g.addEdge(2,4)
print(g)

# %%
import queue
class Graph:
    def __init__(self,nVertices):
        self.nVertices=nVertices
        self.adjMatrix=[[0 for i in range(nVertices)] for j in range(nVertices)]
    
    def addEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=1
        self.adjMatrix[v2][v1]=1
    
    def dfshelper(self,sv,visited):
        print(sv)
        for i in range(self.nVertices):
            if self.adjmatrix[sv][i]>0 and visited[i] is False:
                self.dfshelper(i,visited)
            
        
        
        
        
    def bfs(self):
        visited=[False for i in range(self.nVertices)]
        q=queue.Queue()
        q.put(0)
        u=q.get()
        print(u)
        visited[0]=True
        
        for i in range(self.nVertices):
            while q.empty() is False:
                
                if self.adjmatrix[u][i]>0 and visited[i] is False:
                    q.put(i)
                    visited[i]=True
                    
                    
    
    def dfs(self):
        visited=[False for i in range(self.nVertices)]
        
        self.dfshelper(0,visited)
    def removeEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=0
        self.adjMatrix[v2][v1]=0
        
    def ContainsEdge(self,v1,v2):
        return True if self.adjMatrix[v1][v2]>0 else False
    
    def __str__(self):
        return str(self.adjMatrix)
g=Graph(5)
g.addEdge(0,1)
g.addEdge(1,3)
g.addEdge(2,4)
print(g)

# %% [markdown]
# ## has Path

# %%
import queue
class Graph:
    
 
    def __init__(self,nVertices):
        self.nVertices=nVertices
        self.adjMatrix=[[0 for i in range(nVertices)] for j in range(nVertices)]
    
    def addEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=1
        self.adjMatrix[v2][v1]=1
    
    
    def haspath(self,u,v):
        visited=[False for i in range(self.nVertices)]
        q=queue.Queue()
        q.put(u)
        visited[u]=True
        while q.empty() is False:
            temp=q.get()
            if self.adjMatrix[temp][v]==1:
                return True
            for i in range(self.nVertices):
                if visited[i] is False:
                    q.put(i)
                    visited[i]=True
                    
        return False
    
    
    def dfs(self):
        visited=[False for i in range(self.nVertices)]
        
        self.dfshelper(0,visited)
    def removeEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=0
        self.adjMatrix[v2][v1]=0
        
    def ContainsEdge(self,v1,v2):
        return True if self.adjMatrix[v1][v2]>0 else False
    
    
l=[int(i) for i in input().split()]
V,E=l[0],l[1]
t=Graph(V)
for s in range(E):
    d=[int(i) for i in input().split()]
    a,b=d[0],d[1]
    t.addEdge(a,b)
c=[int(i) for i in input().split()]
u,v=c[0],c[1]
if t.haspath(u,v):
    print("true")
else:
    print("false")

# %%
4 4
0 1
0 3
1 2
2 3
1 3

# %% [markdown]
# ## BFS and DFS For disconnected

# %%
import queue
class Graph:
    def __init__(self,nVertices):
        self.nVertices=nVertices
        self.adjMatrix=[[0 for i in range(nVertices)] for j in range(nVertices)]
    
    def addEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=1
        self.adjMatrix[v2][v1]=1
    
    def dfshelper(self,sv,visited):
        print(sv)
        for i in range(self.nVertices):
            if self.adjmatrix[sv][i]>0 and visited[i] is False:
                self.dfshelper(i,visited)
            
        
        
        
        
    def bfs(self):
        visited=[False for i in range(self.nVertices)]
        q=queue.Queue()
        q.put(0)
        u=q.get()
        print(u)
        visited[0]=True
        
        for i in range(self.nVertices):
            while q.empty() is False:
                
                if self.adjmatrix[u][i]>0 and visited[i] is False:
                    q.put(i)
                    visited[i]=True
                    
                    
    
    def dfs(self):
        visited=[False for i in range(self.nVertices)]
        for i in range(self.nVertices):
            if visited[i]==False:
                self.dfshelper(i,visited)
        
        self.dfshelper(0,visited)
    def removeEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=0
        self.adjMatrix[v2][v1]=0
        
    def ContainsEdge(self,v1,v2):
        return True if self.adjMatrix[v1][v2]>0 else False
    
    def __str__(self):
        return str(self.adjMatrix)
g=Graph(5)
g.addEdge(0,1)
g.addEdge(1,3)
g.addEdge(2,4)
print(g)

# %% [markdown]
# ## GEt path DFS

# %%
import queue
class Graph:
    
 
    def __init__(self,nVertices):
        self.nVertices=nVertices
        self.adjMatrix=[[0 for i in range(nVertices)] for j in range(nVertices)]
    
    def addEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=1
        self.adjMatrix[v2][v1]=1
    
    def printpath(self,li):
        for i in range(len(li)):
            print(i,end=" ")
    def path(self,u,v):
        visited=[False for i in range(self.nVertices)]
        li=[]
        self.pathhelper(u,v,visited,li)

    
    def pathhelper(self,u,v,visited,li):
        visited[u]=True
        li.append(u)
        
        
        
        if self.adjMatrix[u][v]==1:
            print(li)
        
        
        else:
            
            for i in range(self.nVertices):
                if self.adjMatrix[u][i]==1 and visited[i]==False:
                     self.pathhelper(i,v,visited,li)
                        
        li.pop()
        visited[u]=False
                    
                    
                    
                    
        
         
    def dfs(self):
        visited=[False for i in range(self.nVertices)]
        
        self.dfshelper(0,visited)
    def removeEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=0
        self.adjMatrix[v2][v1]=0
        
    def ContainsEdge(self,v1,v2):
        return True if self.adjMatrix[v1][v2]>0 else False
    
    
l=[int(i) for i in input().split()]
V,E=l[0],l[1]
t=Graph(V)
for s in range(E):
    d=[int(i) for i in input().split()]
    a,b=d[0],d[1]
    t.addEdge(a,b)
c=[int(i) for i in input().split()]
u,v=c[0],c[1]
t.path(u,v)

# %%
import queue
class Graph:
    def __init__(self,nVertices):
        self.nVertices=nVertices
        self.adjMatrix=[[0 for i in range(nVertices)] for j in range(nVertices)]
    
    def addEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=1
        self.adjMatrix[v2][v1]=1
    
    def dfshelper(self,sv,visited):
        print(sv)
        for i in range(self.nVertices):
            if self.adjmatrix[sv][i]>0 and visited[i] is False:
                self.dfshelper(i,visited)
            
        
        
        
        
    def bfs(self):
        visited=[False for i in range(self.nVertices)]
        q=queue.Queue()
        q.put(0)
        u=q.get()
        print(u)
        visited[0]=True
        
        for i in range(self.nVertices):
            while q.empty() is False:
                
                if self.adjmatrix[u][i]>0 and visited[i] is False:
                    q.put(i)
                    visited[i]=True
                    
                    
    
    def dfs(self):
        visited=[False for i in range(self.nVertices)]
        for i in range(self.nVertices):
            if visited[i]==False:
                self.dfshelper(i,visited)
        
        self.dfshelper(0,visited)
    def removeEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=0
        self.adjMatrix[v2][v1]=0
        
    def ContainsEdge(self,v1,v2):
        return True if self.adjMatrix[v1][v2]>0 else False
    
    def __str__(self):
        return str(self.adjMatrix)
g=Graph(5)
g.addEdge(0,1)
g.addEdge(1,3)
g.addEdge(2,4)
print(g)

# %%
import queue
class Graph:
    
 
    def __init__(self,nVertices):
        self.nVertices=nVertices
        self.adjMatrix=[[0 for i in range(nVertices)] for j in range(nVertices)]
    
    def addEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=1
        self.adjMatrix[v2][v1]=1
    
    
    def haspath(self,u,v):
        visited=[False for i in range(self.nVertices)]
        q=queue.Queue()
        q.put(u)
        visited[u]=True
        while q.empty() is False:
            temp=q.get()
            if self.adjMatrix[temp][v]==1:
                return True
            for i in range(self.nVertices):
                if visited[i] is False:
                    q.put(i)
                    visited[i]=True
                    
        return False
    
    
    def dfs(self):
        visited=[False for i in range(self.nVertices)]
        
        self.dfshelper(0,visited)
    def removeEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=0
        self.adjMatrix[v2][v1]=0
        
    def ContainsEdge(self,v1,v2):
        return True if self.adjMatrix[v1][v2]>0 else False
    
    
l=[int(i) for i in input().split()]
V,E=l[0],l[1]
t=Graph(V)
for s in range(E):
    d=[int(i) for i in input().split()]
    a,b=d[0],d[1]
    t.addEdge(a,b)

for i in range(V):
    if t.haspath(0,i+1) is False:
        print("false")
        break
print("true")

# %%
import queue
class Graph:
    
 
    def __init__(self,nVertices):
        self.nVertices=nVertices
        self.adjMatrix=[[0 for i in range(nVertices)] for j in range(nVertices)]
    
    def addEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=1
        self.adjMatrix[v2][v1]=1
    
    
    def haspath(self,u,v):
        visited=[False for i in range(self.nVertices)]
        q=queue.Queue()
        q.put(u)
        visited[u]=True
        while q.empty() is False:
            temp=q.get()
            if self.adjMatrix[temp][v]==1:
                return True
            for i in range(self.nVertices):
                if self.adjMatrix[temp][v]== 1 and visited[i] is False:
                    q.put(i)
                    visited[i]=True
                    
        return False
    
    
    def dfs(self):
        visited=[False for i in range(self.nVertices)]
        
        self.dfshelper(0,visited)
    def removeEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=0
        self.adjMatrix[v2][v1]=0
        
    def ContainsEdge(self,v1,v2):
        return True if self.adjMatrix[v1][v2]>0 else False
    
    
l=[int(i) for i in input().split()]
V,E=l[0],l[1]
t=Graph(V)
for s in range(E):
    d=[int(i) for i in input().split()]
    a,b=d[0],d[1]
    t.addEdge(a,b)
temp=[]
for i in range(V-1):
    temp.append(t.haspath(0,i+1))

    
if False in temp:
    print("false")
else:
    print("true")
# if False in temp:
#     print("false")
# else:
#     print("true")

# %%
temp

# %%
import queue
class Graph:
    def __init__(self,nVertices):
        self.nVertices=nVertices
        self.adjMatrix=[[0 for i in range(nVertices)] for j in range(nVertices)]
    
    def addEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=1
        self.adjMatrix[v2][v1]=1

        
        
    def bfs(self,s,d):
        q=queue.Queue()
        q.put(s)
        visited=[False for i in range(self.nVertices)]
        visited[s]=True
        
        while q.empty() is False:
            u=q.get()
            if u==d:
                return True
            for i in range(self.nVertices):
                if (self.adjMatrix[u][i]>0 and visited[i] is False):
                    q.put(i)
                    visited[i]=True
        return False       
                
    def check(self):
        visited=[]
        for i in range(self.nVertices):
            if self.bfs(0,i):
                visited.append(True)
            else:
                visited.append(False)
                
        return visited
        
                
  
    
    
    def removeEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=0
        self.adjMatrix[v2][v1]=0
        
    def ContainsEdge(self,v1,v2):
        return True if self.adjMatrix[v1][v2]>0 else False
    
    def __str__(self):
        return str(self.adjMatrix)
    
    
l=[int(i) for i in input().split()]
V,E=l[0],l[1]
t=Graph(V)
for s in range(E):
    d=[int(i) for i in input().split()]
    a,b=d[0],d[1]
    t.addEdge(a,b)
temp=t.check()


    
if False in temp:
    print("false")
else:
    print("true")

# %% [markdown]
# ## All Connected Component

# %%
import queue
class Graph:
    def __init__(self,nVertices):
        self.nVertices=nVertices
        self.adjMatrix=[[0 for i in range(nVertices)] for j in range(nVertices)]
    
    def addEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=1
        self.adjMatrix[v2][v1]=1

        
        
    def all_connected_component(self,temp,sv,visited):
        
        visited[sv]=True
        temp.append(sv)
        for i in range(self.nVertices):
            if (self.adjMatrix[sv][i]>0 and visited[i] is False):
                temp=self.all_connected_component(temp,i,visited)
                
        return temp
        
        
        
                
    def check(self):
        visited=[False for i in range(self.nVertices)]
        cc=[]
        for i in range(self.nVertices):
            if visited[i]==False:
                temp=[]
                cc.append(self.all_connected_component(temp,i,visited))
       
        return cc
        
            
           
    
    
    def removeEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=0
        self.adjMatrix[v2][v1]=0
        
    def ContainsEdge(self,v1,v2):
        return True if self.adjMatrix[v1][v2]>0 else False
l=[int(i) for i in input().split()]
V,E=l[0],l[1]
t=Graph(V)
for s in range(E):
    d=[int(i) for i in input().split()]
    a,b=d[0],d[1]
    t.addEdge(a,b)
cc=t.check()
for i in range(len(cc)):
    cc[i].sort()
for i in range(len(cc)):
    for j in range(len(cc[i])):
        print(cc[i][j],end=" ")
        
    print()

# %%
# A union by rank and path compression based 
# program to detect cycle in a graph 
from collections import defaultdict 

# a structure to represent a graph 
class Graph:
    

    def __init__(self, num_of_v):
        
        self.num_of_v = num_of_v 
        self.edges = defaultdict(list) 
        
    
    def add_edge(self, u, v):
        
        
        self.edges[u].append(v) 


class Subset:
    
    def __init__(self, parent, rank):
        
        self.parent = parent 
        self.rank = rank 

# A utility function to find set of an element 
# node(uses path compression technique) 
def find(subsets, node):
    
    
    if subsets[node].parent != node: 
        subsets[node].parent = find(subsets, subsets[node].parent) 
    return subsets[node].parent 

# A function that does union of two sets 
# of u and v(uses union by rank) 
def union(subsets, u, v):
    
	
	# Attach smaller rank tree under root 
	# of high rank tree(Union by Rank) 
	if subsets[u].rank > subsets[v].rank: 
		subsets[v].parent = u 
	elif subsets[v].rank > subsets[u].rank: 
		subsets[u].parent = v 
		
	# If ranks are same, then make one as 
	# root and increment its rank by one 
	else: 
		subsets[v].parent = u 
		subsets[u].rank += 1

# The main function to check whether a given 
# graph contains cycle or not 
def isCycle(graph):
    
	
	# Allocate memory for creating sets 
    subsets = [] 

    for u in range(graph.num_of_v): 
        subsets.append(Subset(u, 0)) 
   


    for u in graph.edges: ## u is vertices
        
        
        u_rep = find(subsets, u) 

        for v in graph.edges[u]:
            
            v_rep = find(subsets, v) 

            
            if u_rep == v_rep: 
                return True
            else: 
                union(subsets, u_rep, v_rep) 

# Driver Code 
g = Graph(3)

# add edge 0-1 
g.add_edge(0, 1) 

# add edge 1-2 
g.add_edge(1, 2) 

# add edge 0-2 
g.add_edge(0, 2) 

if isCycle(g): 
	print('Graph contains cycle') 
else: 
	print('Graph does not contain cycle') 

# This code is contributed by 
# Sampath Kumar Surine

# %%
class Edge:
    def __init__(self,src,dest,wt):
        
        self.src=src
        self.dest=dest
        self.wt=wt
        

def getParent(v,parent):
    if (v==parent[v]):
        return v
    return getParent(parent[v],parent)

def krushkal(edges,nVertices):
    parent=[i for i in range(nVertices)]
    edges=sorted(edges,key= lambda edge:edge.wt)
    count=0
    i=0
    output=[]
    while count <(nVertices-1):
        CurrentEdge=edges[i]
        
        srcParent=getParent(CurrentEdge.src,parent)
        
        destParent=getParent(CurrentEdge.dest,parent)
        
        if srcParent != destParent:
            output.append(CurrentEdge)
            count +=1
            parent[srcParent]=destParent
        i +=1
    return output

li=[int(ele) for ele in input().split()]
n,E=li[0],li[1]
edges=[]
for i in range(E):
    curr_input=[int(ele) for ele in input().split()]
    src=curr_input[0]
    dest=curr_input[1]
    wt=curr_input[2]
    edge=Edge(src,dest,wt)
    edges.append(edge)
   
output=krushkal(edges,n)

for edge in output:
    if edge.src < edge.dest:
        print(str(edge.src) + " " +str(edge.dest) + " "  + str(edge.wt))
    else:
        print(str(edge.dest) + " " + str(edge.src) + " "  + str(edge.wt))
# Out:
# 4 4
# 0 1 3
# 0 3 5
# 1 2 1
# 2 3 8
# edges are [<__main__.Edge object at 0x0000013ADFD7CB38>, <__main__.Edge object at 0x0000013ADFE44BE0>, <__main__.Edge object at 0x0000013ADFE44C18>, <__main__.Edge object at 0x0000013ADFE44C50>]
# 1 2 1
# 0 1 3
# 0 3 5

# %%
class Edge:
    def __init__(self,src,dest,wt):
        self.src=src
        self.dest=dest
        self.wt=wt
        
def getparent(v,parent):
    if v==parent[v]:
        return v
    getparent(parent[v],parent)
    
def krushkul(edge,nvertices):
    edge=sorted(edge,key=lambda edges:edges.wt)
    count=0
    i=0
    temp=[]
    parent=[int(i) for i in range(nvertices)]
    while i<(nvertices-1):
        currentedge=edge[i]
        srcparent=getparent(currentedge.src,parent)
        destparent=getparent(currentedge.dest,parent)
        if srcparent!=destparent:
            temp.append(currentedge)
            
            count +=1
        i +=1
    return temp
            
    
    

    
    
    
li=[int(i) for i in input().split()]
v,E=li[0],li[1]
inputt=[]

for i in range(E):
    l=[int(ele) for ele in input().split()]
    src,dest,wt=l[0],l[1],l[2]
    edges=Edge(src,dest,wt)
    inputt.append(edges)
    
output=krushkul(input,v)
for edge in output:
    if edge.src < edge.dest:
        print(str(edge.src) + " " +str(edge.dest) + " "  + str(edge.wt))
    else:
        print(str(edge.dest) + " " + str(edge.src) + " "  + str(edge.wt))
# Out:
# 4 4
# 0 1 3
# 0 3 5
# 1 2 1
# 2 3 8
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-2932f9213bd5> in <module>
#      43     inputt.append(edges)
#      44
# ---> 45 output=krushkul(input,v)
#      46 for edge in output:
#      47     if edge.src < edge.dest:
#
# <ipython-input-1-2932f9213bd5> in krushkul(edge, nvertices)
#      11
#      12 def krushkul(edge,nvertices):
# ---> 13     edge=sorted(edge,key=lambda edges:edges.wt)
#      14     count=0
#      15     i=0
#
# TypeError: 'method' object is not iterable

# %%
4 4
0 1 3
0 3 5
1 2 1
2 3 8

# %%
l=[int(ele) for ele in input().split()]
